# %%
from pydataset import data
import pandas as pd
import numpy as np

import datetime

# %%
# 1. Load the mpg dataset. Read the documentation for it, and use the data to answer 
# these questions:

data('mpg', show_doc=True) # view the documentation for the dataset
# with show_doc=True won't assign data to variable

mpg = data('mpg') # load the dataset and store it in a variable

# %%
# On average, which manufacturer has the best miles per gallon?

# add column of average mpg
mpg['avg_mpg'] = (mpg.cty + mpg.hwy) / 2

# average mpg per manufacturer best on top
mpg.groupby('manufacturer').avg_mpg.mean().sort_values(ascending=False)

# %%
# How many different manufacturers are there?

# use .unique() to get list of unique values, len() will give total count
# https://cmdlinetips.com/2018/01/how-to-get-unique-values-from-a-column-in-pandas-data-frame/
len(mpg.manufacturer.unique())

# %%
# How many different models are there?
# use .unique() to get list of unique values, len() will give total count
len(mpg.model.unique())

# %%
# Do automatic or manual cars have better miles per gallon?
mpg.head()
bools = mpg.trans.str.contains('man')
print("Cars with a manual transmission = True, Automatic Transmission = False")
print("Cars with a manual transmission have a higher average mpg")
mpg.groupby(bools).avg_mpg.mean().sort_values(ascending=False)

# %%
# 2. Joining and Merging
# Copy the users and roles dataframes from the examples above. 

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})


# What do you think a right join would look like? 

# a right join would show all roles (even those without users), but not all users
pd.merge(users, roles, left_on='role_id', right_on='id', how='right')

# %%
#  An outer join?

# an outer join should show all users and all roles inserting null values where needed
pd.merge(users, roles, left_on='role_id', right_on='id', how='outer')

# %%
# What happens if you drop the foreign keys from the dataframes and try to merge them?

# it puts the roles as additional names below the original users
pd.merge(users, roles, how='outer')

# %%
# 3. Getting data from SQL databases
# 3.a. Create a function named get_db_url. It should accept a username, hostname, 
# password, and database name and return a url formatted like in the examples 
# in this lesson.

# from env import host, user, password
# url = f'mysql+pymysql://{user}:{password}@{host}/employees'
# pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)


# for getting from Codeup SQL databases
def get_db_url(database):
    from env import host, user, password
    url = f'mysql+pymysql://{user}:{password}@{host}/{database}'
    return url

# note: this would require typing user and password into jupyter notebook
# which would defeat the purpose of annonimity!
# def general_get_db_url(user, password, host, database):
#     url = f'mysql+pymysql://{user}:{password}@{host}/{database}'
#     return url

# %%
# Ryan's challenge = show all available databases
from env import host, user, password
url = f'mysql+pymysql://{user}:{password}@{host}'
query = '''show databases'''
pd.read_sql(query, url)
# Out:
#               Database
# 0   information_schema
# 1            albums_db
# 2                bayes
# 3            bayes_826
# 4             chipotle
# 5               elo_db
# 6            employees
# 7            fruits_db
# 8              iris_db
# 9      join_example_db
# 10      mall_customers
# 11               mysql
# 12             numbers
# 13           quotes_db
# 14              sakila
# 15              svi_db
# 16         telco_churn
# 17          titanic_db
# 18     tsa_item_demand
# 19               world
# 20              zillow

# %%
# 3.b. Use your function to obtain a connection to the employees database.
# (and run a query)

query = """select * from orders limit 100"""
pd.read_sql(query, get_db_url('chipotle'))
# Out:
#      id  order_id  quantity                              item_name  \
# 0     1         1         1           Chips and Fresh Tomato Salsa
# 1     2         1         1                                   Izze
# 2     3         1         1                       Nantucket Nectar
# 3     4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4     5         2         2                           Chicken Bowl
# 5     6         3         1                           Chicken Bowl
# 6     7         3         1                          Side of Chips
# 7     8         4         1                          Steak Burrito
# 8     9         4         1                       Steak Soft Tacos
# 9    10         5         1                          Steak Burrito
# 10   11         5         1                    Chips and Guacamole
# 11   12         6         1                   Chicken Crispy Tacos
# 12   13         6         1                     Chicken Soft Tacos
# 13   14         7         1                           Chicken Bowl
# 14   15         7         1                    Chips and Guacamole
# 15   16         8         1  Chips and Tomatillo-Green Chili Salsa
# 16   17         8         1                        Chicken Burrito
# 17   18         9         1                        Chicken Burrito
# 18   19         9         2                            Canned Soda
# 19   20        10         1                           Chicken Bowl
# 20   21        10         1                    Chips and Guacamole
# 21   22        11         1                       Barbacoa Burrito
# 22   23        11         1                       Nantucket Nectar
# 23   24        12         1                        Chicken Burrito
# 24   25        12         1                                   Izze
# 25   26        13         1           Chips and Fresh Tomato Salsa
# 26   27        13         1                           Chicken Bowl
# 27   28        14         1                       Carnitas Burrito
# 28   29        14         1                            Canned Soda
# 29   30        15         1                        Chicken Burrito
# 30   31        15         1  Chips and Tomatillo-Green Chili Salsa
# 31   32        16         1                          Steak Burrito
# 32   33        16         1                          Side of Chips
# 33   34        17         1                          Carnitas Bowl
# 34   35        17         1                          Bottled Water
# 35   36        18         1                     Chicken Soft Tacos
# 36   37        18         1                     Chicken Soft Tacos
# 37   38        18         1                    Chips and Guacamole
# 38   39        18         1  Chips and Tomatillo Green Chili Salsa
# 39   40        19         1                          Barbacoa Bowl
# 40   41        19         1                                  Chips
# 41   42        20         1                    Chips and Guacamole
# 42   43        20         1                           Chicken Bowl
# 43   44        20         1                          Steak Burrito
# 44   45        20         1                     Chicken Salad Bowl
# 45   46        21         1                        Chicken Burrito
# 46   47        21         1                          Steak Burrito
# 47   48        21         1                                   Izze
# 48   49        22         1                          Steak Burrito
# 49   50        22         1                    Chips and Guacamole
# 50   51        23         1                          Steak Burrito
# 51   52        23         2                            Canned Soda
# 52   53        24         1                        Chicken Burrito
# 53   54        24         1                            Canned Soda
# 54   55        25         1                             Steak Bowl
# 55   56        25         1           Chips and Fresh Tomato Salsa
# 56   57        26         1                    Barbacoa Soft Tacos
# 57   58        26         1                         Veggie Burrito
# 58   59        27         1                          Barbacoa Bowl
# 59   60        27         1                                  Chips
# 60   61        28         1                    Chips and Guacamole
# 61   62        28         1                       Steak Soft Tacos
# 62   63        28         1                            Veggie Bowl
# 63   64        28         1                        Chicken Burrito
# 64   65        29         1                          Steak Burrito
# 65   66        29         1                       Steak Soft Tacos
# 66   67        30         1                                   Izze
# 67   68        30         1                          Steak Burrito
# 68   69        30         1                        Chicken Burrito
# 69   70        31         1                          Steak Burrito
# 70   71        31         1                          Side of Chips
# 71   72        32         1                          Steak Burrito
# 72   73        32         1                    Chips and Guacamole
# 73   74        33         1                        Chicken Burrito
# 74   75        33         1                    Chips and Guacamole
# 75   76        34         1                     Chicken Soft Tacos
# 76   77        34         1                           Chicken Bowl
# 77   78        34         1                                  Chips
# 78   79        34         1                           Chicken Bowl
# 79   80        35         1                     Chicken Soft Tacos
# 80   81        35         1                                  Chips
# 81   82        36         1                       Barbacoa Burrito
# 82   83        36         1                        Chicken Burrito
# 83   84        37         1                        Chicken Burrito
# 84   85        37         1                       Steak Soft Tacos
# 85   86        38         1                            Veggie Bowl
# 86   87        38         1                             Steak Bowl
# 87   88        38         1                          Bottled Water
# 88   89        39         1                       Carnitas Burrito
# 89   90        39         1           Chips and Fresh Tomato Salsa
# 90   91        40         1                             Steak Bowl
# 91   92        40         1                             Steak Bowl
# 92   93        40         1                     Steak Crispy Tacos
# 93   94        41         1                       Carnitas Burrito
# 94   95        41         1                    Chips and Guacamole
# 95   96        42         1                          Barbacoa Bowl
# 96   97        42         1                    Chips and Guacamole
# 97   98        43         1                          Carnitas Bowl
# 98   99        43         1                        Chicken Burrito
# 99  100        44         1                           Chicken Bowl
#
#                                                                            choice_description  \
# 0                                                                                         nan
# 1                                                                                [Clementine]
# 2                                                                                     [Apple]
# 3                                                                                         nan
# 4                  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 5                 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 6                                                                                         nan
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour...
# 8                   [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 9         [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 10                                                                                        nan
# 11     [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
# 12                        [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 13             [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]
# 14                                                                                        nan
# 15                                                                                        nan
# 16                  [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]
# 17              [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 18                                                                                   [Sprite]
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettu...
# 20                                                                                        nan
# 21  [[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili...
# 22                                                                       [Pomegranate Cherry]
# 23  [[Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Pinto Beans...
# 24                                                                               [Grapefruit]
# 25                                                                                        nan
# 26  [Roasted Chili Corn Salsa (Medium), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 27  [[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Bea...
# 28                                                                               [Dr. Pepper]
# 29            [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]
# 30                                                                                        nan
# 31  [[Roasted Chili Corn Salsa (Medium), Fresh Tomato Salsa (Mild)], [Rice, Black Beans, S...
# 32                                                                                        nan
# 33  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cre...
# 34                                                                                        nan
# 35                                                           [Roasted Chili Corn Salsa, Rice]
# 36                                              [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# 37                                                                                        nan
# 38                                                                                        nan
# 39  [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, ...
# 40                                                                                        nan
# 41                                                                                        nan
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 43          [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 44                            [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
# 45  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Gu...
# 46                          [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajita Veggies, Cheese]]
# 47                                                                               [Blackberry]
# 48  [[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Sa...
# 49                                                                                        nan
# 50   [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]
# 51                                                                             [Mountain Dew]
# 52  [Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 53                                                                                   [Sprite]
# 54       [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]
# 55                                                                                        nan
# 56                            [Fresh Tomato Salsa, [Fajita Vegetables, Black Beans, Lettuce]]
# 57  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream,...
# 58  [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, ...
# 59                                                                                        nan
# 60                                                                                        nan
# 61                                                               [Fresh Tomato Salsa, Cheese]
# 62  [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacam...
# 63                                          [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# 64  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cre...
# 65                     [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]
# 66                                                                               [Blackberry]
# 67                                          [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]
# 68  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Gu...
# 69                       [Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]
# 70                                                                                        nan
# 71        [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 72                                                                                        nan
# 73                       [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 74                                                                                        nan
# 75                           [Tomatillo Red Chili Salsa, [Rice, Cheese, Sour Cream, Lettuce]]
# 76                    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Lettuce]]
# 77                                                                                        nan
# 78                     [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 79                             [Roasted Chili Corn Salsa, [Rice, Cheese, Lettuce, Guacamole]]
# 80                                                                                        nan
# 81                     [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 82                     [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 83                     [Tomatillo Green Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese]]
# 84                                                                [Tomatillo Red Chili Salsa]
# 85  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Black Beans, Rice, Fajita Veggies, Let...
# 86    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Fajita Veggies, Cheese, Lettuce]]
# 87                                                                                        nan
# 88                              [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour Cream, Cheese]]
# 89                                                                                        nan
# 90                   [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole]]
# 91                   [Fresh Tomato Salsa, [Fajita Vegetables, Cheese, Sour Cream, Guacamole]]
# 92                                                           [Fresh Tomato Salsa, Sour Cream]
# 93                                        [Roasted Chili Corn Salsa, [Sour Cream, Guacamole]]
# 94                                                                                        nan
# 95                        [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream]]
# 96                                                                                        nan
# 97   [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]
# 98                                   [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese]]
# 99                [Tomatillo Red Chili Salsa, [Rice, Fajita Vegetables, Sour Cream, Lettuce]]
#
#    item_price
# 0      $2.39
# 1      $3.39
# 2      $3.39
# 3      $2.39
# 4     $16.98
# 5     $10.98
# 6      $1.69
# 7     $11.75
# 8      $9.25
# 9      $9.25
# 10     $4.45
# 11     $8.75
# 12     $8.75
# 13    $11.25
# 14     $4.45
# 15     $2.39
# 16     $8.49
# 17     $8.49
# 18     $2.18
# 19     $8.75
# 20     $4.45
# 21     $8.99
# 22     $3.39
# 23    $10.98
# 24     $3.39
# 25     $2.39
# 26     $8.49
# 27     $8.99
# 28     $1.09
# 29     $8.49
# 30     $2.39
# 31     $8.99
# 32     $1.69
# 33     $8.99
# 34     $1.09
# 35     $8.75
# 36     $8.75
# 37     $4.45
# 38     $2.95
# 39    $11.75
# 40     $2.15
# 41     $4.45
# 42    $11.25
# 43    $11.75
# 44     $8.75
# 45    $10.98
# 46     $8.99
# 47     $3.39
# 48     $8.99
# 49     $3.99
# 50     $8.99
# 51     $2.18
# 52    $10.98
# 53     $1.09
# 54     $8.99
# 55     $2.39
# 56     $9.25
# 57    $11.25
# 58    $11.75
# 59     $2.15
# 60     $4.45
# 61     $9.25
# 62    $11.25
# 63     $8.75
# 64     $8.99
# 65     $8.99
# 66     $3.39
# 67     $8.99
# 68    $10.98
# 69     $8.99
# 70     $1.69
# 71     $8.99
# 72     $3.99
# 73     $8.75
# 74     $4.45
# 75     $8.75
# 76     $8.75
# 77     $2.15
# 78     $8.75
# 79    $11.25
# 80     $2.15
# 81     $9.25
# 82     $8.75
# 83     $8.75
# 84     $9.25
# 85     $8.49
# 86     $8.99
# 87     $1.09
# 88     $9.25
# 89     $2.95
# 90    $11.75
# 91    $11.75
# 92     $9.25
# 93    $11.75
# 94     $4.45
# 95     $9.25
# 96     $4.45
# 97    $11.75
# 98     $8.75
# 99     $8.75

# %%
# 3. Once you have successfully run a query:
# 3.c.i. Intentionally make a typo in the database url. What kind of error message do you see?

# misspell database name
#query = """select * from orders limit 100"""
#pd.read_sql(query, get_db_url('chipotel'))

# spelling error in url, supposed to be pymysql
url = f'mysql+pysql://{user}:{password}@{host}'
query = '''show databases'''
pd.read_sql(query, url)

# %%
# 3.c.ii. Intentionally make an error in your SQL query. What does the error message look like?

# misspell query table name
query = """select * from oders limit 100"""
pd.read_sql(query, get_db_url('chipotle'))

# %%
# 3.d. Read the employees and titles tables into two separate dataframes

# write SQL queries for tables
query_employees = '''select * from employees'''
query_titles = '''select * from titles'''
# url function
url = get_db_url('employees')
# assign tables to df variables
employeesdf = pd.read_sql(query_employees, url)
titlesdf = pd.read_sql(query_titles, url)

# %%
# 3.e. Visualize the number of employees with each title.

# 3.e.i. current data
# get a sense of what titlesdf looks like
titlesdf.head()
# set today's date variable and create bools to filter to_date greater than today
today = pd.to_datetime('today')
today
# Out:
# Timestamp('2020-08-16 14:51:30.201229')

# %%
bools = titlesdf.to_date < today
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-27d3eca5ef0b> in <module>
# ----> 1 bools = titlesdf.to_date < today
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__richcmp__()
#
# TypeError: Cannot compare type 'Timestamp' with type 'date'

# %%
# use the groupby to count the number of employees with that title currently
titlesdf[bools].groupby('title').count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-14caf51b29ce> in <module>
#       6 # set today's date variable and create bools to filter to_date greater than today
#       7 today = pd.to_datetime('today')
# ----> 8 bools = titlesdf.to_date < today
#       9 # use the groupby to count the number of employees with that title currently
#      10 titlesdf[bools].groupby('title').count()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__richcmp__()
#
# TypeError: Cannot compare type 'Timestamp' with type 'date'

# %%
# 3.e.ii. Visualize the number of employees with each title -- for all titles historical
# this will count the historical number of employees with that title
titlesdf.groupby('title').count()

# %%
# 3.f. Join the employees and titles dataframes together.

# get a sense of the columns in the df to join
print(employeesdf.head())
print(titlesdf.head())

# merge dfs on emp_no
emp_with_titles = pd.merge(employeesdf, titlesdf, left_on='emp_no', right_on='emp_no', how='outer')
# show combined head
emp_with_titles.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01

# %%
type(emp_with_titles.to_date[1])
# Out:
# datetime.date

# %%
emp_with_titles['to_date'] - emp_with_titles['from_date']
# Out:
# 0         2926512 days, 0:00:00
# 1         2922821 days, 0:00:00
# 2         2923065 days, 0:00:00
# 3            3287 days, 0:00:00
# 4         2923067 days, 0:00:00
# 5         2922781 days, 0:00:00
# 6            2557 days, 0:00:00
# 7         2925011 days, 0:00:00
# 8         2922995 days, 0:00:00
# 9            2557 days, 0:00:00
# 10            873 days, 0:00:00
# 11           1826 days, 0:00:00
# 12           1826 days, 0:00:00
# 13        2923353 days, 0:00:00
# 14        2922708 days, 0:00:00
# 15           2483 days, 0:00:00
# 16           2922 days, 0:00:00
# 17        2921223 days, 0:00:00
# 18        2926761 days, 0:00:00
# 19        2923769 days, 0:00:00
# 20            337 days, 0:00:00
# 21        2922264 days, 0:00:00
# 22        2921360 days, 0:00:00
# 23           2557 days, 0:00:00
# 24           2922 days, 0:00:00
# 25        2923309 days, 0:00:00
# 443254    2923231 days, 0:00:00
# 443255       2557 days, 0:00:00
# 443256    2922817 days, 0:00:00
# 443257       2191 days, 0:00:00
# 443258    2921308 days, 0:00:00
# 443259    2922758 days, 0:00:00
# 443260       3287 days, 0:00:00
# 443261    2925064 days, 0:00:00
# 443262       1826 days, 0:00:00
# 443263       1657 days, 0:00:00
# 443264    2922756 days, 0:00:00
# 443265       1826 days, 0:00:00
# 443266    2922098 days, 0:00:00
# 443267    2923393 days, 0:00:00
# 443268       1389 days, 0:00:00
# 443269       3287 days, 0:00:00
# 443270    2921979 days, 0:00:00
# 443271    2923735 days, 0:00:00
# 443272    2922691 days, 0:00:00
# 443273        610 days, 0:00:00
# 443274    2925598 days, 0:00:00
# 443275    2921579 days, 0:00:00
# 443276        523 days, 0:00:00
# 443277    2922795 days, 0:00:00
# 443278    2921899 days, 0:00:00
# 443279       2922 days, 0:00:00
# 443280    2921510 days, 0:00:00
# 443281       3287 days, 0:00:00
# 443282        404 days, 0:00:00
# 443283    2921015 days, 0:00:00
# 443284       2191 days, 0:00:00
# 443285       1826 days, 0:00:00
# 443286    2923556 days, 0:00:00
# 443287    2922629 days, 0:00:00
# 443288    2924274 days, 0:00:00
# 443289       2557 days, 0:00:00
# 443290    2921586 days, 0:00:00
# 443291       1537 days, 0:00:00
# 443292       3287 days, 0:00:00
# 443293       1590 days, 0:00:00
# 443294    2921640 days, 0:00:00
# 443295    2922629 days, 0:00:00
# 443296    2924368 days, 0:00:00
# 443297       1826 days, 0:00:00
# 443298    2922574 days, 0:00:00
# 443299        247 days, 0:00:00
# 443300    2922518 days, 0:00:00
# 443301       2191 days, 0:00:00
# 443302    2920712 days, 0:00:00
# 443303       1826 days, 0:00:00
# 443304    2924256 days, 0:00:00
# 443305    2921945 days, 0:00:00
# 443306       1826 days, 0:00:00
# 443307    2922337 days, 0:00:00
# Length: 443308, dtype: object

# %%
# 3.g. Visualize how frequently employees change titles.

# find type of data in to_date and from_date columns
type(emp_with_titles.to_date)

# exobrain http://chris35wills.github.io/time_elapsed_pandas/
# columns are objects, pandas timedelta works on objects
# per exobrain https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timedelta.html

# replace future to_date to today for calculations
#df['column name'] = df['column name'].replace(['old value'],'new value')
# today = pd.to_datetime('today')
# print(today)
# to = pd.to_datetime(emp_with_titles.to_date, yearfirst=True) 
# today = pd.to_datetime('today')
# bools = titlesdf.to_date < today 
# emp_with_titles['calc_date'] = emp_with_titles.to_date[bools]

# df_test['Difference'] = df_test['First_Date'].sub(df_test['Second Date'], axis=0)
# df_test.head()

emp_with_titles['to_date'] - emp_with_titles['from_date']


# calculate time in position for all (include historic) and add as column
# exobrain http://www.datasciencemadesimple.com/difference-two-dates-days-weeks-months-years-pandas-python-2/
#emp_with_titles['time_in_position'] = emp_with_titles['to_date'] - emp_with_titles['from_date']
#emp_with_titles['time_in_position']=df['diff_years']/np.timedelta64(1,'Y')
# Out:
# 0         2926512 days, 0:00:00
# 1         2922821 days, 0:00:00
# 2         2923065 days, 0:00:00
